# %% [markdown]
# <a href="https://colab.research.google.com/github/mtrrn1016/SC/blob/main/sc_4week.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <소창 4주차 수업>

# %% [markdown]
# ## 코랩 사용법

# %% [markdown]
# ## print() 함수

# %%
print("안녕하세요")
print(123)
print(123, "안녕하세요")
print("안녕하세요", "반가워요")
# Out:
# 안녕하세요
# 123
# 123 안녕하세요
# 안녕하세요 반가워요

# %%
#안녕하세요
print("안녕하세요")
print(123)
# Out:
# 안녕하세요
# 123

# %% [markdown]
# ## 자료형
#
# string, int, float, bool

# %%
print(type("안녕하세요"))
print(type(123))
print(type(123.123))
print(type(True))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
print("안녕하세요")
print(type("안녕하세요"))
print('안녕하세요')
print(type('안녕하세요'))
# Out:
# 안녕하세요
# <class 'str'>
# 안녕하세요
# <class 'str'>

# %% [markdown]
# **\", \', \n, \t, \\**

# %%
print('"안녕하세요"라고 말했습니다.')
print("'안녕하세요'라고 말했습니다.")
print("\"안녕하세요\"라고 말했습니다.")
print('\'안녕하세요\'라고 말했습니다.')
# Out:
# "안녕하세요"라고 말했습니다.
# '안녕하세요'라고 말했습니다.
# "안녕하세요"라고 말했습니다.
# '안녕하세요'라고 말했습니다.

# %%
print("안녕하세요\n안녕하세요")
print("안녕\t안녕")
print("안녕하세요\\안녕하세요")
# Out:
# 안녕하세요
# 안녕하세요
# 안녕	안녕
# 안녕하세요\안녕하세요

# %%
print(True)
print(type(True))
print(False)
print(type(False))
# Out:
# True
# <class 'bool'>
# False
# <class 'bool'>

# %% [markdown]
# ## 혼자해보기

# %%
print(type('Hello Python!'))
print(type("123"))
print(type(123))
print(type(3.14))
print(type(True))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# ## 변수
#
# 변수이름 = 문자, 숫자, 언더바_ *(파이썬 예약어x, 숫자로 시작x)*
#
#
# 대문자, 소문자 구분함

# %%
number = 100
print(number)
# Out:
# 100

# %%
myAlphabet = 'A'
print(myAlphabet)
# Out:
# A

# %%
myAlphabet = 'A'
print(myAlphabet)
myAlphabet = 'B'
print(myAlphabet)
# Out:
# A
# B

# %%
#keyword.kwlist 명령어를 이용해 파이썬 지정단어 출력
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# True=3  # True는 예약어이므로 변수 이름으로 사용할 수 없습니다.
# 3apples=56 # 변수 이름은 숫자로 시작할 수 없습니다.
# elif=78 # elif는 예약어이므로 변수 이름으로 사용할 수 없습니다.
new_score=90
brother=12
# print(True) # True는 예약어이므로 출력할 수 없습니다.
# print(3apples) # 변수 이름이 유효하지 않습니다.
# print(elif) # elif는 예약어이므로 출력할 수 없습니다.
print(new_score)
print(brother)
# Out:
# 90
# 12

# %%
myName = "구민화"
myMajor = "정보보호학과"
print(myName)
print(myMajor)
# Out:
# 구민화
# 정보보호학과

# %%
intro='Hello'
print(intro)
intro='안녕하세요'
print(intro)
# Out:
# Hello
# 안녕하세요
